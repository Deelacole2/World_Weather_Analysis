# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\deela\anaconda3\envs\pythondata\lib\site-packages (2.24.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\deela\anaconda3\envs\pythondata\lib\site-packages (from requests) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\deela\anaconda3\envs\pythondata\lib\site-packages (from requests) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\deela\anaconda3\envs\pythondata\lib\site-packages (from requests) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\deela\anaconda3\envs\pythondata\lib\site-packages (from requests) (1.25.11)

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy as cp

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# !jupyter nbextension list
# Out:
#       - Validating: ok
#       - Validating: ok
# Known nbextensions:
#   config dir: C:\Users\DeeLa\anaconda3\envs\PythonData\etc\jupyter\nbconfig
#     notebook section
#       jupyter-js-widgets/extension enabled
#       jupyter-gmaps/extension enabled

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=07a1f57ae1b33f062d09abfe013dd8d4

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = cp.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 720

# %%
city_url = url + "&q=" + 'Boston'
city_weather = requests.get(city_url).json()
city_weather
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02d'}],
#  'base': 'stations',
#  'main': {'temp': 27.79,
#   'feels_like': 11.35,
#   'temp_min': 26.01,
#   'temp_max': 30,
#   'pressure': 1011,
#   'humidity': 37},
#  'visibility': 10000,
#  'wind': {'speed': 18.41, 'deg': 300, 'gust': 26.46},
#  'clouds': {'all': 20},
#  'dt': 1611431164,
#  'sys': {'type': 1,
#   'id': 3486,
#   'country': 'US',
#   'sunrise': 1611403540,
#   'sunset': 1611438379},
#  'timezone': -18000,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description": city_weather_description,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except Exception as e:
        print(f"City not found. Skipping...: Error - {e}")
        pass


# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | batemans bay
# Processing Record 2 of Set 1 | barentsburg
# City not found. Skipping...: Error - 'coord'
# Processing Record 3 of Set 1 | new norfolk
# Processing Record 4 of Set 1 | cape town
# Processing Record 5 of Set 1 | sept-iles
# Processing Record 6 of Set 1 | taolanaro
# City not found. Skipping...: Error - 'coord'
# Processing Record 7 of Set 1 | butaritari
# Processing Record 8 of Set 1 | salalah
# Processing Record 9 of Set 1 | gamba
# Processing Record 10 of Set 1 | tabiauea
# City not found. Skipping...: Error - 'coord'
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | ketchikan
# Processing Record 13 of Set 1 | saint-felicien
# Processing Record 14 of Set 1 | hobart
# Processing Record 15 of Set 1 | hithadhoo
# Processing Record 16 of Set 1 | port alfred
# Processing Record 17 of Set 1 | cintalapa
# Processing Record 18 of Set 1 | rawson
# Processing Record 19 of Set 1 | port elizabeth
# Processing Record 20 of Set 1 | catamarca
# Processing Record 21 of Set 1 | ongandjera
# Processing Record 22 of Set 1 | thompson
# Processing Record 23 of Set 1 | sorvag
# City not found. Skipping...: Error - 'coord'
# Processing Record 24 of Set 1 | matara
# Processing Record 25 of Set 1 | blackfoot
# Processing Record 26 of Set 1 | east london
# Processing Record 27 of Set 1 | saskylakh
# Processing Record 28 of Set 1 | bethel
# Processing Record 29 of Set 1 | tasiilaq
# Processing Record 30 of Set 1 | khatanga
# Processing Record 31 of Set 1 | bartlesville
# Processing Record 32 of Set 1 | olinda
# Processing Record 33 of Set 1 | tiksi
# Processing Record 34 of Set 1 | hermanus
# Processing Record 35 of Set 1 | nagaur
# Processing Record 36 of Set 1 | foz
# Processing Record 37 of Set 1 | cabo san lucas
# Processing Record 38 of Set 1 | pacific grove
# Processing Record 39 of Set 1 | punta arenas
# Processing Record 40 of Set 1 | hofn
# Processing Record 41 of Set 1 | ihosy
# Processing Record 42 of Set 1 | daru
# Processing Record 43 of Set 1 | pevek
# Processing Record 44 of Set 1 | kahului
# Processing Record 45 of Set 1 | darhan
# Processing Record 46 of Set 1 | westport
# Processing Record 47 of Set 1 | campo maior
# Processing Record 48 of Set 1 | alice springs
# Processing Record 49 of Set 1 | kalmar
# Processing Record 50 of Set 1 | atuona
# Processing Record 1 of Set 2 | upernavik
# Processing Record 2 of Set 2 | arraial do cabo
# Processing Record 3 of Set 2 | lolua
# City not found. Skipping...: Error - 'coord'
# Processing Record 4 of Set 2 | saint-philippe
# Processing Record 5 of Set 2 | caravelas
# Processing Record 6 of Set 2 | itainopolis
# Processing Record 7 of Set 2 | puerto ayacucho
# Processing Record 8 of Set 2 | yellowknife
# Processing Record 9 of Set 2 | taltal
# Processing Record 10 of Set 2 | victoria
# Processing Record 11 of Set 2 | ribeira grande
# Processing Record 12 of Set 2 | bethanien
# Processing Record 13 of Set 2 | marcona
# City not found. Skipping...: Error - 'coord'
# Processing Record 14 of Set 2 | olafsvik
# Processing Record 15 of Set 2 | rikitea
# Processing Record 16 of Set 2 | luderitz
# Processing Record 17 of Set 2 | estelle
# Processing Record 18 of Set 2 | mys shmidta
# City not found. Skipping...: Error - 'coord'
# Processing Record 19 of Set 2 | iqaluit
# Processing Record 20 of Set 2 | torbay
# Processing Record 21 of Set 2 | georgetown
# Processing Record 22 of Set 2 | tuggurt
# City not found. Skipping...: Error - 'coord'
# Processing Record 23 of Set 2 | pangnirtung
# Processing Record 24 of Set 2 | tuy hoa
# Processing Record 25 of Set 2 | pachino
# Processing Record 26 of Set 2 | tres palos
# Processing Record 27 of Set 2 | bluff
# Processing Record 28 of Set 2 | karamea
# City not found. Skipping...: Error - 'coord'
# Processing Record 29 of Set 2 | busselton
# Processing Record 30 of Set 2 | albany
# Processing Record 31 of Set 2 | ngukurr
# City not found. Skipping...: Error - 'coord'
# Processing Record 32 of Set 2 | kortkeros
# Processing Record 33 of Set 2 | komsomolskiy
# Processing Record 34 of Set 2 | belogorsk
# Processing Record 35 of Set 2 | miami
# Processing Record 36 of Set 2 | nuuk
# Processing Record 37 of Set 2 | traunstein
# Processing Record 38 of Set 2 | huaibei
# Processing Record 39 of Set 2 | tokur
# Processing Record 40 of Set 2 | umm durman
# City not found. Skipping...: Error - 'coord'
# Processing Record 41 of Set 2 | almaznyy
# Processing Record 42 of Set 2 | bengkulu
# Processing Record 43 of Set 2 | galveston
# Processing Record 44 of Set 2 | baruun-urt
# Processing Record 45 of Set 2 | saldanha
# Processing Record 46 of Set 2 | chuy
# Processing Record 47 of Set 2 | samarai
# Processing Record 48 of Set 2 | rio gallegos
# Processing Record 49 of Set 2 | vilhena
# Processing Record 50 of Set 2 | isangel
# Processing Record 1 of Set 3 | zhigansk
# Processing Record 2 of Set 3 | coos bay
# Processing Record 3 of Set 3 | chokurdakh
# Processing Record 4 of Set 3 | mutsamudu
# City not found. Skipping...: Error - 'coord'
# Processing Record 5 of Set 3 | esperance
# Processing Record 6 of Set 3 | batagay-alyta
# Processing Record 7 of Set 3 | samusu
# City not found. Skipping...: Error - 'coord'
# Processing Record 8 of Set 3 | bubaque
# Processing Record 9 of Set 3 | fuling
# Processing Record 10 of Set 3 | bathsheba
# Processing Record 11 of Set 3 | pisco
# Processing Record 12 of Set 3 | sitka
# Processing Record 13 of Set 3 | clyde river
# Processing Record 14 of Set 3 | severo-kurilsk
# Processing Record 15 of Set 3 | illoqqortoormiut
# City not found. Skipping...: Error - 'coord'
# Processing Record 16 of Set 3 | karacabey
# Processing Record 17 of Set 3 | inirida
# Processing Record 18 of Set 3 | dikson
# Processing Record 19 of Set 3 | bima
# Processing Record 20 of Set 3 | muroto
# Processing Record 21 of Set 3 | niquelandia
# Processing Record 22 of Set 3 | aswan
# Processing Record 23 of Set 3 | barbastro
# Processing Record 24 of Set 3 | duma
# Processing Record 25 of Set 3 | tilichiki
# Processing Record 26 of Set 3 | vyshkov
# Processing Record 27 of Set 3 | lutry
# Processing Record 28 of Set 3 | san jeronimo
# Processing Record 29 of Set 3 | sinnamary
# Processing Record 30 of Set 3 | talnakh
# Processing Record 31 of Set 3 | asau
# Processing Record 32 of Set 3 | souillac
# Processing Record 33 of Set 3 | kamenskoye
# City not found. Skipping...: Error - 'coord'
# Processing Record 34 of Set 3 | oruro
# Processing Record 35 of Set 3 | puerto ayora
# Processing Record 36 of Set 3 | hilo
# Processing Record 37 of Set 3 | abha
# Processing Record 38 of Set 3 | el alto
# Processing Record 39 of Set 3 | mataura
# Processing Record 40 of Set 3 | lahij
# Processing Record 41 of Set 3 | vaitupu
# City not found. Skipping...: Error - 'coord'
# Processing Record 42 of Set 3 | balaipungut
# Processing Record 43 of Set 3 | goudomp
# City not found. Skipping...: Error - 'coord'
# Processing Record 44 of Set 3 | barrow
# Processing Record 45 of Set 3 | plettenberg bay
# Processing Record 46 of Set 3 | robertsport
# Processing Record 47 of Set 3 | jamestown
# Processing Record 48 of Set 3 | ahipara
# Processing Record 49 of Set 3 | comodoro rivadavia
# Processing Record 50 of Set 3 | betare oya
# Processing Record 1 of Set 4 | urcos
# Processing Record 2 of Set 4 | lebu
# Processing Record 3 of Set 4 | mergui
# City not found. Skipping...: Error - 'coord'
# Processing Record 4 of Set 4 | antofagasta
# Processing Record 5 of Set 4 | tashla
# Processing Record 6 of Set 4 | san patricio
# Processing Record 7 of Set 4 | lagoa
# Processing Record 8 of Set 4 | faanui
# Processing Record 9 of Set 4 | vaini
# Processing Record 10 of Set 4 | peniche
# Processing Record 11 of Set 4 | sao filipe
# Processing Record 12 of Set 4 | kaitangata
# Processing Record 13 of Set 4 | iranshahr
# Processing Record 14 of Set 4 | trairi
# Processing Record 15 of Set 4 | tabialan
# City not found. Skipping...: Error - 'coord'
# Processing Record 16 of Set 4 | jaisalmer
# Processing Record 17 of Set 4 | amapa
# Processing Record 18 of Set 4 | jabiru
# City not found. Skipping...: Error - 'coord'
# Processing Record 19 of Set 4 | hamilton
# Processing Record 20 of Set 4 | new castle
# Processing Record 21 of Set 4 | ulladulla
# Processing Record 22 of Set 4 | puerto pinasco
# City not found. Skipping...: Error - 'coord'
# Processing Record 23 of Set 4 | cherskiy
# Processing Record 24 of Set 4 | makaha
# Processing Record 25 of Set 4 | hasaki
# Processing Record 26 of Set 4 | mahebourg
# Processing Record 27 of Set 4 | kirensk
# Processing Record 28 of Set 4 | calvinia
# Processing Record 29 of Set 4 | tigre
# Processing Record 30 of Set 4 | vangaindrano
# Processing Record 31 of Set 4 | boguchany
# Processing Record 32 of Set 4 | hambantota
# Processing Record 33 of Set 4 | chernushka
# Processing Record 34 of Set 4 | saint george
# Processing Record 35 of Set 4 | fortuna
# Processing Record 36 of Set 4 | avarua
# Processing Record 37 of Set 4 | kongolo
# Processing Record 38 of Set 4 | pozhva
# Processing Record 39 of Set 4 | anadyr
# Processing Record 40 of Set 4 | san rafael
# Processing Record 41 of Set 4 | mareeba
# Processing Record 42 of Set 4 | astana
# Processing Record 43 of Set 4 | bargal
# City not found. Skipping...: Error - 'coord'
# Processing Record 44 of Set 4 | thyboron
# Processing Record 45 of Set 4 | nizhneyansk
# City not found. Skipping...: Error - 'coord'
# Processing Record 46 of Set 4 | tagusao
# Processing Record 47 of Set 4 | naryan-mar
# Processing Record 48 of Set 4 | makakilo city
# Processing Record 49 of Set 4 | brokopondo
# Processing Record 50 of Set 4 | tsihombe
# City not found. Skipping...: Error - 'coord'
# Processing Record 1 of Set 5 | kichera
# Processing Record 2 of Set 5 | leningradskiy
# Processing Record 3 of Set 5 | kilindoni
# Processing Record 4 of Set 5 | port blair
# Processing Record 5 of Set 5 | yei
# Processing Record 6 of Set 5 | dunedin
# Processing Record 7 of Set 5 | qasigiannguit
# Processing Record 8 of Set 5 | giyon
# Processing Record 9 of Set 5 | puerto madryn
# Processing Record 10 of Set 5 | halifax
# Processing Record 11 of Set 5 | longyearbyen
# Processing Record 12 of Set 5 | kruisfontein
# Processing Record 13 of Set 5 | inhambane
# Processing Record 14 of Set 5 | bredasdorp
# Processing Record 15 of Set 5 | hokitika
# Processing Record 16 of Set 5 | pakwach
# City not found. Skipping...: Error - 'coord'
# Processing Record 17 of Set 5 | belushya guba
# City not found. Skipping...: Error - 'coord'
# Processing Record 18 of Set 5 | la palma
# Processing Record 19 of Set 5 | jinka
# Processing Record 20 of Set 5 | vieux fort
# Processing Record 21 of Set 5 | pundaguitan
# Processing Record 22 of Set 5 | grand river south east
# City not found. Skipping...: Error - 'coord'
# Processing Record 23 of Set 5 | san-pedro
# Processing Record 24 of Set 5 | mazyr
# Processing Record 25 of Set 5 | kloulklubed
# Processing Record 26 of Set 5 | tromso
# Processing Record 27 of Set 5 | luganville
# Processing Record 28 of Set 5 | hami
# Processing Record 29 of Set 5 | kiama
# Processing Record 30 of Set 5 | trat
# Processing Record 31 of Set 5 | mar del plata
# Processing Record 32 of Set 5 | date
# Processing Record 33 of Set 5 | haines junction
# Processing Record 34 of Set 5 | abonnema
# Processing Record 35 of Set 5 | vila franca do campo
# Processing Record 36 of Set 5 | high level
# Processing Record 37 of Set 5 | zhezkazgan
# Processing Record 38 of Set 5 | konotop
# Processing Record 39 of Set 5 | muros
# Processing Record 40 of Set 5 | axim
# Processing Record 41 of Set 5 | airai
# Processing Record 42 of Set 5 | havelock
# Processing Record 43 of Set 5 | carnarvon
# Processing Record 44 of Set 5 | ponta do sol
# Processing Record 45 of Set 5 | wasilla
# Processing Record 46 of Set 5 | grand forks
# Processing Record 47 of Set 5 | sistranda
# Processing Record 48 of Set 5 | paredon
# Processing Record 49 of Set 5 | kapaa
# Processing Record 50 of Set 5 | shemursha
# Processing Record 1 of Set 6 | lorengau
# Processing Record 2 of Set 6 | inta
# Processing Record 3 of Set 6 | roma
# Processing Record 4 of Set 6 | flinders
# Processing Record 5 of Set 6 | geraldton
# Processing Record 6 of Set 6 | hirara
# Processing Record 7 of Set 6 | hualmay
# Processing Record 8 of Set 6 | moscow
# Processing Record 9 of Set 6 | port macquarie
# Processing Record 10 of Set 6 | vicuna
# Processing Record 11 of Set 6 | caborca
# Processing Record 12 of Set 6 | cap malheureux
# Processing Record 13 of Set 6 | glendive
# Processing Record 14 of Set 6 | bandarbeyla
# Processing Record 15 of Set 6 | dodoma
# Processing Record 16 of Set 6 | brigantine
# Processing Record 17 of Set 6 | wajid
# Processing Record 18 of Set 6 | yerbogachen
# Processing Record 19 of Set 6 | castro
# Processing Record 20 of Set 6 | copiapo
# Processing Record 21 of Set 6 | meilu
# City not found. Skipping...: Error - 'coord'
# Processing Record 22 of Set 6 | klaksvik
# Processing Record 23 of Set 6 | ambilobe
# Processing Record 24 of Set 6 | cayenne
# Processing Record 25 of Set 6 | rezekne
# Processing Record 26 of Set 6 | kodiak
# Processing Record 27 of Set 6 | nanortalik
# Processing Record 28 of Set 6 | narsaq
# Processing Record 29 of Set 6 | tungkang
# City not found. Skipping...: Error - 'coord'
# Processing Record 30 of Set 6 | roth
# Processing Record 31 of Set 6 | umm kaddadah
# Processing Record 32 of Set 6 | dhidhdhoo
# Processing Record 33 of Set 6 | balabac
# Processing Record 34 of Set 6 | ostrovnoy
# Processing Record 35 of Set 6 | tocopilla
# Processing Record 36 of Set 6 | mahuva
# Processing Record 37 of Set 6 | bonthe
# Processing Record 38 of Set 6 | fairbanks
# Processing Record 39 of Set 6 | qaanaaq
# Processing Record 40 of Set 6 | lasa
# Processing Record 41 of Set 6 | merauke
# Processing Record 42 of Set 6 | nikolskoye
# Processing Record 43 of Set 6 | mon
# Processing Record 44 of Set 6 | sorong
# Processing Record 45 of Set 6 | umzimvubu
# City not found. Skipping...: Error - 'coord'
# Processing Record 46 of Set 6 | sur
# Processing Record 47 of Set 6 | tuktoyaktuk
# Processing Record 48 of Set 6 | cockburn town
# Processing Record 49 of Set 6 | port pirie
# Processing Record 50 of Set 6 | huarmey
# Processing Record 1 of Set 7 | tautira
# Processing Record 2 of Set 7 | panaba
# Processing Record 3 of Set 7 | sao joao da barra
# Processing Record 4 of Set 7 | lichinga
# Processing Record 5 of Set 7 | la ronge
# Processing Record 6 of Set 7 | klyuchi
# Processing Record 7 of Set 7 | san cristobal
# Processing Record 8 of Set 7 | pangody
# Processing Record 9 of Set 7 | haibowan
# City not found. Skipping...: Error - 'coord'
# Processing Record 10 of Set 7 | padang
# Processing Record 11 of Set 7 | katsuura
# Processing Record 12 of Set 7 | krasnogorsk
# Processing Record 13 of Set 7 | unity
# Processing Record 14 of Set 7 | taburi
# City not found. Skipping...: Error - 'coord'
# Processing Record 15 of Set 7 | sentyabrskiy
# City not found. Skipping...: Error - 'coord'
# Processing Record 16 of Set 7 | meulaboh
# Processing Record 17 of Set 7 | mtwara
# Processing Record 18 of Set 7 | kieta
# Processing Record 19 of Set 7 | cidreira
# Processing Record 20 of Set 7 | carlsbad
# Processing Record 21 of Set 7 | manapparai
# Processing Record 22 of Set 7 | tabou
# Processing Record 23 of Set 7 | srednekolymsk
# Processing Record 24 of Set 7 | namibe
# Processing Record 25 of Set 7 | mogadishu
# Processing Record 26 of Set 7 | arlit
# Processing Record 27 of Set 7 | kjollefjord
# Processing Record 28 of Set 7 | tunkas
# Processing Record 29 of Set 7 | yaring
# Processing Record 30 of Set 7 | nogliki
# Processing Record 31 of Set 7 | lavrentiya
# Processing Record 32 of Set 7 | khorixas
# Processing Record 33 of Set 7 | verkhnyaya inta
# Processing Record 34 of Set 7 | port hedland
# Processing Record 35 of Set 7 | bengkalis
# City not found. Skipping...: Error - 'coord'
# Processing Record 36 of Set 7 | celestun
# Processing Record 37 of Set 7 | dubinino
# Processing Record 38 of Set 7 | puro
# Processing Record 39 of Set 7 | guerrero negro
# Processing Record 40 of Set 7 | tahoua
# Processing Record 41 of Set 7 | saleaula
# City not found. Skipping...: Error - 'coord'
# Processing Record 42 of Set 7 | mindelo
# Processing Record 43 of Set 7 | kaili
# Processing Record 44 of Set 7 | rolim de moura
# City not found. Skipping...: Error - 'coord'
# Processing Record 45 of Set 7 | khuzdar
# Processing Record 46 of Set 7 | ayagoz
# Processing Record 47 of Set 7 | kakamega
# Processing Record 48 of Set 7 | hurghada
# Processing Record 49 of Set 7 | cusuna
# Processing Record 50 of Set 7 | norfolk
# Processing Record 1 of Set 8 | laredo
# Processing Record 2 of Set 8 | ornskoldsvik
# Processing Record 3 of Set 8 | flin flon
# Processing Record 4 of Set 8 | nantucket
# Processing Record 5 of Set 8 | marzuq
# Processing Record 6 of Set 8 | challapata
# Processing Record 7 of Set 8 | mount isa
# Processing Record 8 of Set 8 | beidao
# Processing Record 9 of Set 8 | kuryk
# Processing Record 10 of Set 8 | katherine
# Processing Record 11 of Set 8 | zaria
# Processing Record 12 of Set 8 | seymchan
# Processing Record 13 of Set 8 | zhicheng
# Processing Record 14 of Set 8 | kavaratti
# Processing Record 15 of Set 8 | amazar
# Processing Record 16 of Set 8 | kamina
# Processing Record 17 of Set 8 | vila velha
# Processing Record 18 of Set 8 | muisne
# Processing Record 19 of Set 8 | meadow lake
# Processing Record 20 of Set 8 | aklavik
# Processing Record 21 of Set 8 | oistins
# Processing Record 22 of Set 8 | wadi musa
# Processing Record 23 of Set 8 | mantoudion
# City not found. Skipping...: Error - 'coord'
# Processing Record 24 of Set 8 | suntar
# Processing Record 25 of Set 8 | saint-pierre
# Processing Record 26 of Set 8 | djambala
# Processing Record 27 of Set 8 | launceston
# Processing Record 28 of Set 8 | akdepe
# Processing Record 29 of Set 8 | coolum beach
# Processing Record 30 of Set 8 | amderma
# City not found. Skipping...: Error - 'coord'
# Processing Record 31 of Set 8 | mackenzie
# Processing Record 32 of Set 8 | bowen
# Processing Record 33 of Set 8 | altamira
# Processing Record 34 of Set 8 | banff
# Processing Record 35 of Set 8 | noumea
# Processing Record 36 of Set 8 | ituni
# City not found. Skipping...: Error - 'coord'
# Processing Record 37 of Set 8 | jinchang
# Processing Record 38 of Set 8 | abu dhabi
# Processing Record 39 of Set 8 | yanam
# Processing Record 40 of Set 8 | sazava
# Processing Record 41 of Set 8 | tevaitoa
# Processing Record 42 of Set 8 | houma
# Processing Record 43 of Set 8 | havre
# Processing Record 44 of Set 8 | jalu
# Processing Record 45 of Set 8 | weligama
# Processing Record 46 of Set 8 | guozhen
# Processing Record 47 of Set 8 | nenjiang
# Processing Record 48 of Set 8 | falam
# Processing Record 49 of Set 8 | teguldet
# Processing Record 50 of Set 8 | torrevieja
# Processing Record 1 of Set 9 | college
# Processing Record 2 of Set 9 | pochutla
# Processing Record 3 of Set 9 | lompoc
# Processing Record 4 of Set 9 | codrington
# Processing Record 5 of Set 9 | constitucion
# Processing Record 6 of Set 9 | beringovskiy
# Processing Record 7 of Set 9 | bacolod
# Processing Record 8 of Set 9 | omboue
# Processing Record 9 of Set 9 | makat
# Processing Record 10 of Set 9 | alofi
# Processing Record 11 of Set 9 | severo-yeniseyskiy
# Processing Record 12 of Set 9 | manzhouli
# Processing Record 13 of Set 9 | ilhabela
# Processing Record 14 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 15 of Set 9 | bilibino
# Processing Record 16 of Set 9 | buin
# Processing Record 17 of Set 9 | talawdi
# City not found. Skipping...: Error - 'coord'
# Processing Record 18 of Set 9 | half moon bay
# Processing Record 19 of Set 9 | thinadhoo
# Processing Record 20 of Set 9 | kavieng
# Processing Record 21 of Set 9 | masaguisi
# Processing Record 22 of Set 9 | linqiong
# Processing Record 23 of Set 9 | sumbawa
# City not found. Skipping...: Error - 'coord'
# Processing Record 24 of Set 9 | antalaha
# Processing Record 25 of Set 9 | kumbo
# Processing Record 26 of Set 9 | bolshoye ignatovo
# City not found. Skipping...: Error - 'coord'
# Processing Record 27 of Set 9 | wawa
# Processing Record 28 of Set 9 | kaduna
# Processing Record 29 of Set 9 | port augusta
# Processing Record 30 of Set 9 | urumqi
# Processing Record 31 of Set 9 | aliaga
# Processing Record 32 of Set 9 | tuatapere
# Processing Record 33 of Set 9 | asyut
# Processing Record 34 of Set 9 | bonoua
# Processing Record 35 of Set 9 | mitsamiouli
# Processing Record 36 of Set 9 | kushalgarh
# Processing Record 37 of Set 9 | pandan
# Processing Record 38 of Set 9 | taoudenni
# Processing Record 39 of Set 9 | labuhan
# Processing Record 40 of Set 9 | beira
# Processing Record 41 of Set 9 | attawapiskat
# City not found. Skipping...: Error - 'coord'
# Processing Record 42 of Set 9 | puerto leguizamo
# Processing Record 43 of Set 9 | bichura
# Processing Record 44 of Set 9 | paicandu
# Processing Record 45 of Set 9 | phalaborwa
# Processing Record 46 of Set 9 | marion
# Processing Record 47 of Set 9 | cozumel
# Processing Record 48 of Set 9 | hit
# Processing Record 49 of Set 9 | ongwediva
# Processing Record 50 of Set 9 | arrecife
# Processing Record 1 of Set 10 | farah
# Processing Record 2 of Set 10 | ocos
# Processing Record 3 of Set 10 | eyl
# Processing Record 4 of Set 10 | gisborne
# Processing Record 5 of Set 10 | adrar
# Processing Record 6 of Set 10 | olot
# Processing Record 7 of Set 10 | iuna
# Processing Record 8 of Set 10 | turbat
# Processing Record 9 of Set 10 | pavda
# City not found. Skipping...: Error - 'coord'
# Processing Record 10 of Set 10 | arman
# Processing Record 11 of Set 10 | viedma
# Processing Record 12 of Set 10 | bokspits
# City not found. Skipping...: Error - 'coord'
# Processing Record 13 of Set 10 | muravlenko
# Processing Record 14 of Set 10 | qaqortoq
# Processing Record 15 of Set 10 | aloleng
# Processing Record 16 of Set 10 | vytegra
# Processing Record 17 of Set 10 | urgut
# Processing Record 18 of Set 10 | harrisonburg
# Processing Record 19 of Set 10 | melfi
# Processing Record 20 of Set 10 | agapovka
# Processing Record 21 of Set 10 | vanimo
# Processing Record 22 of Set 10 | tazovskiy
# Processing Record 23 of Set 10 | prince george
# Processing Record 24 of Set 10 | yenagoa
# Processing Record 25 of Set 10 | sosnovka
# Processing Record 26 of Set 10 | porto velho
# Processing Record 27 of Set 10 | denpasar
# Processing Record 28 of Set 10 | mehamn
# Processing Record 29 of Set 10 | tailai
# Processing Record 30 of Set 10 | bulalacao
# Processing Record 31 of Set 10 | najran
# Processing Record 32 of Set 10 | uruzgan
# Processing Record 33 of Set 10 | tarko-sale
# Processing Record 34 of Set 10 | trinidad
# Processing Record 35 of Set 10 | price
# Processing Record 36 of Set 10 | baherden
# Processing Record 37 of Set 10 | kemin
# Processing Record 38 of Set 10 | hay river
# Processing Record 39 of Set 10 | knoxville
# Processing Record 40 of Set 10 | deputatskiy
# Processing Record 41 of Set 10 | elizabeth city
# Processing Record 42 of Set 10 | artyk
# City not found. Skipping...: Error - 'coord'
# Processing Record 43 of Set 10 | fort nelson
# Processing Record 44 of Set 10 | roald
# Processing Record 45 of Set 10 | liepaja
# Processing Record 46 of Set 10 | palabuhanratu
# City not found. Skipping...: Error - 'coord'
# Processing Record 47 of Set 10 | bata
# Processing Record 48 of Set 10 | dali
# Processing Record 49 of Set 10 | shepsi
# Processing Record 50 of Set 10 | mount gambier
# Processing Record 1 of Set 11 | rassvet
# Processing Record 2 of Set 11 | kazalinsk
# City not found. Skipping...: Error - 'coord'
# Processing Record 3 of Set 11 | mitu
# Processing Record 4 of Set 11 | havoysund
# Processing Record 5 of Set 11 | grindavik
# Processing Record 6 of Set 11 | kuche
# City not found. Skipping...: Error - 'coord'
# Processing Record 7 of Set 11 | hellin
# Processing Record 8 of Set 11 | macau
# Processing Record 9 of Set 11 | sao joao dos patos
# Processing Record 10 of Set 11 | malanje
# Processing Record 11 of Set 11 | port hardy
# Processing Record 12 of Set 11 | sobolevo
# Processing Record 13 of Set 11 | balimo
# City not found. Skipping...: Error - 'coord'
# Processing Record 14 of Set 11 | tarrafal
# Processing Record 15 of Set 11 | vadso
# Processing Record 16 of Set 11 | te anau
# Processing Record 17 of Set 11 | san pedro
# Processing Record 18 of Set 11 | sedelnikovo
# City not found. Skipping...: Error - 'coord'
# Processing Record 19 of Set 11 | killybegs
# Processing Record 20 of Set 11 | naze
# Processing Record 21 of Set 11 | laishevo
# Processing Record 22 of Set 11 | akyab
# Processing Record 23 of Set 11 | ilulissat
# Processing Record 24 of Set 11 | fukue
# Processing Record 25 of Set 11 | tacuarembo
# Processing Record 26 of Set 11 | toliary
# City not found. Skipping...: Error - 'coord'
# Processing Record 27 of Set 11 | lago da pedra
# Processing Record 28 of Set 11 | buluang
# Processing Record 29 of Set 11 | bogorodskoye
# Processing Record 30 of Set 11 | acurenam
# Processing Record 31 of Set 11 | hudson bay
# Processing Record 32 of Set 11 | gatesville
# Processing Record 33 of Set 11 | provideniya
# Processing Record 34 of Set 11 | riberalta
# Processing Record 35 of Set 11 | podosinovets
# Processing Record 36 of Set 11 | griffith
# Processing Record 37 of Set 11 | auki
# Processing Record 38 of Set 11 | baran
# Processing Record 39 of Set 11 | senador jose porfirio
# Processing Record 40 of Set 11 | los llanos de aridane
# Processing Record 41 of Set 11 | matamoros
# Processing Record 42 of Set 11 | rafaela
# Processing Record 43 of Set 11 | kismayo
# Processing Record 44 of Set 11 | lichtenburg
# Processing Record 45 of Set 11 | north battleford
# Processing Record 46 of Set 11 | rosetta
# Processing Record 47 of Set 11 | erzurum
# Processing Record 48 of Set 11 | san quintin
# Processing Record 49 of Set 11 | mormugao
# Processing Record 50 of Set 11 | alyangula
# Processing Record 1 of Set 12 | garowe
# Processing Record 2 of Set 12 | ust-karsk
# Processing Record 3 of Set 12 | bairiki
# Processing Record 4 of Set 12 | banjarmasin
# Processing Record 5 of Set 12 | bakel
# Processing Record 6 of Set 12 | westpunt
# City not found. Skipping...: Error - 'coord'
# Processing Record 7 of Set 12 | aranda de duero
# Processing Record 8 of Set 12 | vardo
# Processing Record 9 of Set 12 | campbeltown
# Processing Record 10 of Set 12 | cairo
# Processing Record 11 of Set 12 | palmer
# Processing Record 12 of Set 12 | gopalpur
# Processing Record 13 of Set 12 | porto-vecchio
# Processing Record 14 of Set 12 | benxi
# Processing Record 15 of Set 12 | burica
# City not found. Skipping...: Error - 'coord'
# Processing Record 16 of Set 12 | edson
# Processing Record 17 of Set 12 | mirabad
# Processing Record 18 of Set 12 | mihijam
# Processing Record 19 of Set 12 | kirakira
# Processing Record 20 of Set 12 | tahe
# Processing Record 21 of Set 12 | babanusah
# City not found. Skipping...: Error - 'coord'
# Processing Record 22 of Set 12 | mugur-aksy
# Processing Record 23 of Set 12 | ruston
# Processing Record 24 of Set 12 | sabang
# Processing Record 25 of Set 12 | praia
# Processing Record 26 of Set 12 | taiyuan
# Processing Record 27 of Set 12 | xichang
# Processing Record 28 of Set 12 | winnemucca
# Processing Record 29 of Set 12 | ponta delgada
# Processing Record 30 of Set 12 | kenai
# Processing Record 31 of Set 12 | oktyabrskiy
# Processing Record 32 of Set 12 | carsamba
# Processing Record 33 of Set 12 | udachnyy
# Processing Record 34 of Set 12 | san jose
# Processing Record 35 of Set 12 | ahuimanu
# Processing Record 36 of Set 12 | yazoo city
# Processing Record 37 of Set 12 | prince rupert
# Processing Record 38 of Set 12 | zemio
# Processing Record 39 of Set 12 | douglas
# Processing Record 40 of Set 12 | evensk
# Processing Record 41 of Set 12 | contamana
# Processing Record 42 of Set 12 | wattegama
# Processing Record 43 of Set 12 | marechal candido rondon
# Processing Record 44 of Set 12 | kazaki
# Processing Record 45 of Set 12 | morehead
# Processing Record 46 of Set 12 | shingu
# Processing Record 47 of Set 12 | avera
# Processing Record 48 of Set 12 | port lincoln
# Processing Record 49 of Set 12 | goderich
# Processing Record 50 of Set 12 | liku
# Processing Record 1 of Set 13 | kurmanayevka
# Processing Record 2 of Set 13 | dandong
# Processing Record 3 of Set 13 | alexandria
# Processing Record 4 of Set 13 | sooke
# Processing Record 5 of Set 13 | rubizhne
# Processing Record 6 of Set 13 | alugan
# Processing Record 7 of Set 13 | quatre cocos
# Processing Record 8 of Set 13 | karratha
# Processing Record 9 of Set 13 | ust-kamchatsk
# City not found. Skipping...: Error - 'coord'
# Processing Record 10 of Set 13 | kupang
# Processing Record 11 of Set 13 | angoche
# Processing Record 12 of Set 13 | shirdi
# Processing Record 13 of Set 13 | passage west
# Processing Record 14 of Set 13 | fare
# Processing Record 15 of Set 13 | clifton
# Processing Record 16 of Set 13 | maarianhamina
# Processing Record 17 of Set 13 | cairns
# Processing Record 18 of Set 13 | ozinki
# Processing Record 19 of Set 13 | san juan
# Processing Record 20 of Set 13 | kamenka
# Processing Record 21 of Set 13 | lodja
# Processing Record 22 of Set 13 | laizhou
# Processing Record 23 of Set 13 | tigil
# Processing Record 24 of Set 13 | norman wells
# Processing Record 25 of Set 13 | syava
# Processing Record 26 of Set 13 | oranjemund
# Processing Record 27 of Set 13 | narasannapeta
# Processing Record 28 of Set 13 | sola
# Processing Record 29 of Set 13 | mehran
# Processing Record 30 of Set 13 | yeniseysk
# Processing Record 31 of Set 13 | tessaoua
# Processing Record 32 of Set 13 | malwan
# City not found. Skipping...: Error - 'coord'
# Processing Record 33 of Set 13 | nayudupeta
# Processing Record 34 of Set 13 | piacabucu
# Processing Record 35 of Set 13 | termiz
# Processing Record 36 of Set 13 | horsens
# Processing Record 37 of Set 13 | harrisonville
# Processing Record 38 of Set 13 | lethem
# Processing Record 39 of Set 13 | mlonggo
# Processing Record 40 of Set 13 | xinyu
# Processing Record 41 of Set 13 | ndjole
# Processing Record 42 of Set 13 | vanderhoof
# Processing Record 43 of Set 13 | kijang
# Processing Record 44 of Set 13 | morant bay
# Processing Record 45 of Set 13 | rabo de peixe
# Processing Record 46 of Set 13 | patan
# Processing Record 47 of Set 13 | saint-louis
# Processing Record 48 of Set 13 | tselinnoye
# Processing Record 49 of Set 13 | pierre
# Processing Record 50 of Set 13 | ambikapur
# Processing Record 1 of Set 14 | kenora
# Processing Record 2 of Set 14 | poum
# Processing Record 3 of Set 14 | ormara
# Processing Record 4 of Set 14 | zmeinogorsk
# Processing Record 5 of Set 14 | orai
# Processing Record 6 of Set 14 | san luis
# Processing Record 7 of Set 14 | staraya kulatka
# Processing Record 8 of Set 14 | namatanai
# Processing Record 9 of Set 14 | powell
# Processing Record 10 of Set 14 | lafia
# Processing Record 11 of Set 14 | vostok
# Processing Record 12 of Set 14 | santa rosa
# Processing Record 13 of Set 14 | kamaishi
# Processing Record 14 of Set 14 | barbar
# City not found. Skipping...: Error - 'coord'
# Processing Record 15 of Set 14 | tual
# Processing Record 16 of Set 14 | laguna
# Processing Record 17 of Set 14 | te horo
# Processing Record 18 of Set 14 | tura
# Processing Record 19 of Set 14 | nhulunbuy
# Processing Record 20 of Set 14 | niamey
# Processing Record 21 of Set 14 | sofiysk
# City not found. Skipping...: Error - 'coord'
# Processing Record 22 of Set 14 | synya
# Processing Record 23 of Set 14 | bonnyville
# Processing Record 24 of Set 14 | hearst
# Processing Record 25 of Set 14 | sibu
# Processing Record 26 of Set 14 | olga
# Processing Record 27 of Set 14 | irtyshskiy
# Processing Record 28 of Set 14 | simiti
# Processing Record 29 of Set 14 | hervey bay
# Processing Record 30 of Set 14 | basoko
# Processing Record 31 of Set 14 | kuching
# Processing Record 32 of Set 14 | moussoro
# Processing Record 33 of Set 14 | ranau
# Processing Record 34 of Set 14 | newport
# Processing Record 35 of Set 14 | jaguaquara
# Processing Record 36 of Set 14 | santa luzia
# Processing Record 37 of Set 14 | teahupoo
# Processing Record 38 of Set 14 | ulkan
# Processing Record 39 of Set 14 | kulhudhuffushi
# Processing Record 40 of Set 14 | hammerfest
# Processing Record 41 of Set 14 | santa maria del oro
# Processing Record 42 of Set 14 | tapes
# Processing Record 43 of Set 14 | turukhansk
# Processing Record 44 of Set 14 | xiaoshi
# Processing Record 45 of Set 14 | huilong
# Processing Record 46 of Set 14 | durban
# Processing Record 47 of Set 14 | xining
# Processing Record 48 of Set 14 | ola
# Processing Record 49 of Set 14 | novo lino
# Processing Record 50 of Set 14 | lingyuan
# Processing Record 1 of Set 15 | ca mau
# Processing Record 2 of Set 15 | dahra
# Processing Record 3 of Set 15 | tezu
# Processing Record 4 of Set 15 | altay
# Processing Record 5 of Set 15 | rundu
# Processing Record 6 of Set 15 | redmond
# Processing Record 7 of Set 15 | yarkovo
# Processing Record 8 of Set 15 | podporozhye
# Processing Record 9 of Set 15 | dolbeau
# City not found. Skipping...: Error - 'coord'
# Processing Record 10 of Set 15 | felidhoo
# City not found. Skipping...: Error - 'coord'
# Processing Record 11 of Set 15 | zolotinka
# City not found. Skipping...: Error - 'coord'
# Processing Record 12 of Set 15 | verkhniye tatyshly
# Processing Record 13 of Set 15 | florence
# Processing Record 14 of Set 15 | hobyo
# Processing Record 15 of Set 15 | marfino
# Processing Record 16 of Set 15 | wahran
# City not found. Skipping...: Error - 'coord'
# Processing Record 17 of Set 15 | haicheng
# Processing Record 18 of Set 15 | kandrian
# Processing Record 19 of Set 15 | nelson bay
# Processing Record 20 of Set 15 | rasinari
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(len(city_data))
# Out:
# 657

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Batemans Bay -35.7167  150.1833     66.00        94          10
# 1     New Norfolk -42.7826  147.0587     55.99        74           5
# 2       Cape Town -33.9258   18.4232     68.00        94          75
# 3       Sept-Iles  50.2001  -66.3821     21.00        79         100
# 4      Butaritari   3.0707  172.7902     79.45        81          95
# 5         Salalah  17.0151   54.0924     73.40        23           0
# 6           Gamba  -2.6500   10.0000     77.02        87         100
# 7         Ushuaia -54.8000  -68.3000     60.80        41          75
# 8       Ketchikan  55.3422 -131.6461     32.00       100          90
# 9  Saint-Felicien  48.6501  -72.4491     12.20        67          20
#
#    Wind Speed Weather Description Country                 Date
# 0        1.01           clear sky      AU  2021-01-23 19:39:37
# 1        2.53           clear sky      AU  2021-01-23 19:39:57
# 2       14.97          light rain      ZA  2021-01-23 19:38:58
# 3       10.36          light snow      CA  2021-01-23 19:39:00
# 4       11.86     overcast clouds      KI  2021-01-23 19:39:15
# 5       10.36           clear sky      OM  2021-01-23 19:39:58
# 6        1.61     overcast clouds      GA  2021-01-23 19:39:58
# 7       10.58          light rain      AR  2021-01-23 19:39:28
# 8        5.75                mist      US  2021-01-23 19:39:58
# 9       17.27          few clouds      CA  2021-01-23 19:39:58

# %%
new_column_order = ["City", "Country", "Date", "Lat","Lng", "Max Temp", "Humidity","Cloudiness","Wind Speed", "Weather Description"]

# %%
city_data_df = city_data_df[new_column_order]

city_data_df.head(10)
# Out:
#              City Country                 Date      Lat       Lng  Max Temp  \
# 0    Batemans Bay      AU  2021-01-23 19:39:37 -35.7167  150.1833     66.00
# 1     New Norfolk      AU  2021-01-23 19:39:57 -42.7826  147.0587     55.99
# 2       Cape Town      ZA  2021-01-23 19:38:58 -33.9258   18.4232     68.00
# 3       Sept-Iles      CA  2021-01-23 19:39:00  50.2001  -66.3821     21.00
# 4      Butaritari      KI  2021-01-23 19:39:15   3.0707  172.7902     79.45
# 5         Salalah      OM  2021-01-23 19:39:58  17.0151   54.0924     73.40
# 6           Gamba      GA  2021-01-23 19:39:58  -2.6500   10.0000     77.02
# 7         Ushuaia      AR  2021-01-23 19:39:28 -54.8000  -68.3000     60.80
# 8       Ketchikan      US  2021-01-23 19:39:58  55.3422 -131.6461     32.00
# 9  Saint-Felicien      CA  2021-01-23 19:39:58  48.6501  -72.4491     12.20
#
#    Humidity  Cloudiness  Wind Speed Weather Description
# 0        94          10        1.01           clear sky
# 1        74           5        2.53           clear sky
# 2        94          75       14.97          light rain
# 3        79         100       10.36          light snow
# 4        81          95       11.86     overcast clouds
# 5        23           0       10.36           clear sky
# 6        87         100        1.61     overcast clouds
# 7        41          75       10.58          light rain
# 8       100          90        5.75                mist
# 9        67          20       17.27          few clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
